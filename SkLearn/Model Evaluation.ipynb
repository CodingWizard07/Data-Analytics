# %%
import pandas as pd
import numpy as  np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Evaluation of a ML model

# %% [markdown]
# #### 4.1.a. using `Score` method over classification

# %%
#importing the dataset
hd = pd.read_csv("E:\Datasets\data\heart-disease.csv")
hd.head()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\User\AppData\Local\Temp\ipykernel_1252\1130398519.py:2: SyntaxWarning: invalid escape sequence '\D'
#   hd = pd.read_csv("E:\Datasets\data\heart-disease.csv")
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
#creating a random seed
np.random.seed(42)
#split the data in X and y
X = hd.drop('target',axis=1)
y = hd['target']

#perform a train test split 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

#creating classifier instance
clf = RandomForestClassifier(n_estimators=100)

#fit X_train, y_train
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
clf.score(X_train, y_train)
# Out:
# 1.0

# %%
clf.score(X_test, y_test)
# Out:
# 0.8524590163934426

# %% [markdown]
# #### 4.1.b. using `Score()` method over regression

# %%
from sklearn.datasets import fetch_california_housing
housing = fetch_california_housing()
housing_df = pd.DataFrame(housing["data"], columns=housing["feature_names"])
housing_df["target"] = housing["target"]
housing_df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  target
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

np.random.seed(42)

X = housing_df.drop("target", axis = 1)
y = housing_df["target"]

X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.2)

model = RandomForestRegressor(n_estimators=200)
model.fit(X_train,y_train)

y_preds = model.predict(X_test)

# %%
model.score(X_test,y_test)
# Out:
# 0.8066650267043768

# %% [markdown]
# #### 4.2 using `Score()` parameter

# %%
#classification - heart disease

# %%
clf.score(X_test,y_test)
# Out:
# 0.8524590163934426

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(clf,X,y,cv=5)
# Out:
# array([0.81967213, 0.86885246, 0.81967213, 0.78333333, 0.76666667])

# %%
print(f"clf_single_score = {clf.score(X_test,y_test)}")
print(f"clf_cross_val_score = {np.mean(cross_val_score(clf,X,y,cv=10))}")
# Out:
# clf_single_score = 0.8524590163934426
# clf_cross_val_score = 0.8313978494623656
